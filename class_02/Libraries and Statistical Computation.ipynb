# %% [markdown]
# ### Libraries to be used
#
# - Numpy
# - Matplotlib
# - Pandas
# - OpenCV

# %%
# import the libraries
import numpy as np
#import pandas as pd
import matplotlib.pylab as plt
import matplotlib.pylab as plt1
import cv2
import scipy as sp

# %% [markdown]
# ### Numpy Arrays and Operations

# %%
# Convert lists to numpy arrays
li = [[2,3],[5,6]]
arr1 = np.array(li,dtype = np.uint8)
arr2 = np.asarray(li,dtype = np.float32)


#print(arr1)
#print(arr2)

#print(li , type(li))
#print(arr1 , type(arr1),arr1.dtype)
#print(arr2 , type(arr2),arr2.dtype)

li1 = list(arr1)

#print(li1)              

arr3 = np.eye(5)
arr4 = np.zeros((3,4))
arr5 = np.ones((4,9))

#print(arr3)
#print(arr4)
#print(arr5)

#print(arr3[0][0])

arr6 = np.copy(arr5)

arr7 = np.ones((3,4))

np.copyto(arr7,arr4)

#print(arr6)
#print(arr7)

# Reshape, Transpose, Concatenate numpy arrays

arr8 = np.random.randint(low = -5 , high = 5 , size = (4,6))

#print(arr8)

arr9 = np.concatenate(arr8)

#print(arr9)

arr10 = arr8.T

#print(arr10)

arr11 = np.array([[1,2],[4,5]])
arr12 = np.array([[7,8],[10,11]])

arr13 = np.concatenate((arr11,arr12), axis = 1)
arr14 = np.concatenate((arr11,arr12.T), axis = 0)
#print(arr13)
#print(arr14)

arr15 = np.concatenate((np.expand_dims(arr11, axis =1),np.expand_dims(arr12, axis =1)),axis = 1)
print(arr15.shape)
print(arr15)
# Out:
# (2, 2, 2)
# [[[ 1  2]
#   [ 7  8]]
#
#  [[ 4  5]
#   [10 11]]]

# %%
arr15 = np.concatenate((np.expand_dims

# %%
arr15 = np.concatenate((np.expand_dims

# %%
arr9 = np.concatenate

# %%
arr9 = np.concatenate

# %%
arr8 = np.random.randint

# %%
arr5 = np.ones

# %%
arr5 = np.ones

# %%
arr4 = np.zeros

# %%
arr = np.eye

# %% [markdown]
# ### Matplotlib

# %%
plt.style.available
# Out:
# ['seaborn-darkgrid',
#  'Solarize_Light2',
#  'seaborn-notebook',
#  'classic',
#  'seaborn-ticks',
#  'grayscale',
#  'bmh',
#  'seaborn-talk',
#  'dark_background',
#  'ggplot',
#  'fivethirtyeight',
#  '_classic_test',
#  'seaborn-colorblind',
#  'seaborn-deep',
#  'seaborn-whitegrid',
#  'seaborn',
#  'seaborn-poster',
#  'seaborn-bright',
#  'seaborn-muted',
#  'seaborn-paper',
#  'seaborn-white',
#  'fast',
#  'seaborn-pastel',
#  'seaborn-dark',
#  'tableau-colorblind10',
#  'seaborn-dark-palette']

# %%
# plot simple ranges

# %%
# Plot sine wave, cosine wave, and some lines
t = sp.arange(0, 10, 1/100)
plt.plot(t, sp.sin(1.7 * 2 * sp.pi * t) + sp.sin(1.9 * 2 * sp.pi * t))
plt.show()

# %% [markdown]
# ### OpenCV and Scikit-Image

# %%
# Loading an image

img = cv2.imread("./download.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#print (img.shape)
plt1.imshow(img,cmap = 'gray')


# Dispalying an image

#plt.imshow(img)

# Convert image to grayscale

#plt.imshow(img,cmap='gray')

# Resize image

#print (img.shape)
#reimg = cv2.resize(img,(150,100))
#print(reimg.shape)
#plt.imshow(reimg,cmap = 'gray')

# Cropped Image

#crop_img = img[0:200,0:100]
#print(crop_img.shape)
#plt.imshow(crop_img)
#cv2.imshow("cropped",crop_img)
#cv2.waitKey(0)





# Cropping an Image. Use numpy slicing.
#img = cv2.imread("lenna.png")
#crop_img = img[y:y+h, x:x+w]
#cv2.imshow("cropped", crop_img)
#cv2.waitKey(0)




# Grid ni aa rhe
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) not working
# how to show multiple figures in console
# where we can use cv2.imshow()
# cv2.waitKey crashes on passing values 1
# Why quality lowers on resizing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-907a70c272cf> in <module>()
#       1 # Loading an image
#       2
# ----> 3 img = cv2.imread("./download.jpg")
#       4 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       5 print (img.shape)
#
# NameError: name 'cv2' is not defined

# %% [markdown]
# ### Pandas

# %%
# Load the movie meta-data dataset

# %%
# Get the values as numpy array and check shape

# %%
# Print all columns

# %%
# Print a few movie titles

# %% [markdown]
# ### Mean, Variance, Std. Dev.
#
# Mean:
#
# $$\mu = \frac{\sum_{i}{x_i}}{N}$$
#
# Variance:
#
# $$ Var(x) = \frac{\sum_i(x_i - \mu)^2}{N} $$
#
# Std. deviation:
#
# $$ \sigma_x = \sqrt{\frac{\sum_i(x_i - \mu)^2}{N}} $$
#
# ### Co-Variance
#
# $$
# \Sigma =
# \begin{bmatrix}
#     \sigma^2_{11}       & \sigma^2_{12} & \sigma^2_{13} & \dots & \sigma^2_{1n} \\
#     \sigma^2_{21}       & \sigma^2_{22} & \sigma^2_{23} & \dots & \sigma^2_{2n} \\
#     \dots \\
#     \sigma^2_{n1}       & \sigma^2_{n2} & \sigma^2_{n3} & \dots & \sigma^2_{nn}
# \end{bmatrix}
# $$

# %% [markdown]
# 1. __Random Variable__
# 2. __Distribution Function__:
#     - The _cumulative distribution function_: $F_X(x) = \mathbb{P}(X \leq x)$
#     - Bernoulli Distribution function: $f(x) = p^x(1-p)^{1-x};   x \in \{0, 1\}$
#     - Binomial distribution...
# 3. __Normal Distribution__:
# $$ f(x) = \frac{1}{\sigma \sqrt{2 \pi}} exp\{- \frac{1}{2 \sigma^2} (x - \mu)^2 \} $$
# 4. __Standard Normal Distribution__

# %%
# Create and plot frequency of each title length

# %% [markdown]
# ### Assignment-2

# %%
# Generating random numbers

# (a:0.5, b:0.2, c:0.3)

import random

li = random.choices?
# Out:
# Object `random.choices` not found.

# %%
li = random.choices

# %%
li = random.choice

# %%
# Plot Random numbers as scatter plot

# %%
# Generate Normal distribution in 2D
mean = [0, 0]
cov = [[1, 2], [50, 100]]  # diagonal covariance
x, y = np.random.multivariate_normal(mean, cov, 5000).T
plt.plot(x, y, 'x')
plt.axis('equal')
plt.show()
# Out:
# /home/abhishek/.local/lib/python2.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   after removing the cwd from sys.path.

# %%
# Convert to Standard Normal Distribution
#np.random.normal?
import numpy as np
import matplotlib.pyplot as plt

class norm1:
    def __init__(self, a1, b1, c1):
        self.a1 = a1
        self.b1 = b1
        self.c1 = c1
        
    def dist_curve(self):
        plt.plot(self.c1, 1/(self.b1 * np.sqrt(2 * np.pi)) *
            np.exp( - (self.c1 - self.a1)**2 / (2 * self.b1**2) ), linewidth=2, color='y')
        plt.show()

#Vary the mean and SD to generate different plots
mean1 = 5
sd1 = 2

c = np.random.normal(mean1, sd1, 3000)
        
w1, x1, z1 = plt.hist(c, 100, normed=True) #hist

hist1 = norm1(mean1, sd1, x1)
plot1 = hist1.dist_curve()

# %%
li=[]
for i in range(100):
    x=np.random.random()
    if(x<=0.5):
        li.append("a")
    if(x>0.5 and x<=0.7):
        li.append("b")
    if(x>0.7):
        li.append("c")    
print(li)

np.unique(li, return_counts = True)
# Out:
# ['b', 'c', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'b', 'c', 'b', 'c', 'c', 'a', 'b', 'a', 'a', 'b', 'b', 'a', 'a', 'a', 'c', 'c', 'c', 'b', 'a', 'a', 'a', 'a', 'c', 'a', 'a', 'b', 'c', 'c', 'a', 'c', 'c', 'a', 'a', 'a', 'a', 'c', 'a', 'b', 'c', 'a', 'a', 'a', 'a', 'b', 'b', 'a', 'a', 'a', 'b', 'b', 'c', 'b', 'a', 'a', 'b', 'c', 'c', 'a', 'a', 'c', 'c', 'c', 'b', 'a', 'a', 'a', 'b', 'c', 'a', 'b', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'b', 'a', 'b', 'c', 'a', 'c', 'a', 'a', 'b', 'b', 'c']
# (array(['a', 'b', 'c'], dtype='|S1'), array([54, 22, 24]))

# %%
stdev = np.array([6., 1.])
mean = np.array([2., 0.5])
cov = corr2cov(corr, stdev)

 # `size` is the length of time series for 2d data
 # (500 months, days, and so on).
data = np.random.multivariate_normal(mean=mean, cov=cov, size=500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-146-7d1d76ec22de> in <module>()
#       1 stdev = np.array([6., 1.])
#       2 mean = np.array([2., 0.5])
# ----> 3 cov = corr2cov(corr, stdev)
#       4
#       5  # `size` is the length of time series for 2d data
#
# NameError: name 'corr2cov' is not defined

# %%
# plot the normal and standard normal distribution.

# %%
n = int(input())

for i in range(1,n):
    for j in range(i,n+1):
        print(j,end = ' ')
    print('')
# Out:
#   File "<ipython-input-100-63393fae13fe>", line 5
#     print(j,end = ' ')
#                 ^
# SyntaxError: invalid syntax
